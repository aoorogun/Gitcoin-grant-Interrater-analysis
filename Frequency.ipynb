# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dries = ## Import the datasets for each reviewer here.
david = ## Import the datasets for each reviewer here.
zerb = ## Import the datasets for each reviewer here.
bfa = ## Import the datasets for each reviewer here.
pascal = ## Import the datasets for each reviewer here.
pavel = ## Import the datasets for each reviewer here.
jammie = ## Import the datasets for each reviewer here.
walter = ## Import the datasets for each reviewer here.
chance = ## Import the datasets for each reviewer here.
ann =  ## Import the datasets for each reviewer here.
dogg =  ## Import the datasets for each reviewer here.
sid = ## Import the datasets for each reviewer here
joe =  ## Import the datasets for each reviewer here.
fizzy =  ## Import the datasets for each reviewer here.
am =  ## Import the datasets for each reviewer here.
mount =  ## Import the datasets for each reviewer here.
vik =  ## Import the datasets for each reviewer here.
emmanuel =  ## Import the datasets for each reviewer here.
greg =  ## Import the datasets for each reviewer here.
lkh =  ## Import the datasets for each reviewer here.

# %%
lkh.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
dries.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
david.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
zerb.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
bfa.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
pascal.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
pavel.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
jammie.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
walter.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
chance.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
ann.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
dogg.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
sid.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
joe.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
fizzy.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
am.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
mount.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
vik.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
emmanuel.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)
greg.rename(columns = {'Unnamed: 0' : 'Names'},  inplace = True)

# %%
merged_data = pd.concat([david,  greg, dries, lkh, zerb, bfa, pascal, pavel, jammie, walter, chance, ann, dogg, sid, joe, fizzy, am, mount, vik, emmanuel])

# %%
len(merged_data.dropna()["Names"].unique())
# Out:
# 756

# %%
dataa = [david,  greg, dries, lkh, zerb, bfa, pascal, pavel, jammie, walter, chance, ann, dogg, sid, joe, fizzy, am, mount, vik, emmanuel]

# %%
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

# %%
three = []

for i in dataa:
    for j in handles:
        if j in i.Names.values:
            three.append([namestr(i, globals()), j])

# %%
x=0
for i in range(len(three)):
    if "zkfib" in three[i]:
        x+=1
        print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
three
# Out:
# [[['david', 'i', '_280'], 'zkfib'],
#  [['greg', 'i'], 'fanffu'],
#  [['greg', 'i'], 'zkfib'],
#  [['greg', 'i'], 'imgsu'],
#  [['dries', 'i'], 'bhaumik'],
#  [['dries', 'i'], 'gaojianclare'],
#  [['dries', 'i'], 'jcarvajalmunera'],
#  [['dries', 'i'], 'wmike10'],
#  [['dries', 'i'], 'celir'],
#  [['dries', 'i'], 'owocki'],
#  [['dries', 'i'], 'robocups'],
#  [['lkh', 'i'], 'jcarvajalmunera'],
#  [['lkh', 'i'], 'drbalikci'],
#  [['lkh', 'i'], 'owocki'],
#  [['lkh', 'i'], 'kuangzhicheng203'],
#  [['zerb', 'i'], 'bhaumik'],
#  [['zerb', 'i'], 'drbalikci'],
#  [['bfa', 'i'], 'gaojianclare'],
#  [['bfa', 'i'], 'wmike10'],
#  [['pascal', 'i'], 'fanffu'],
#  [['pascal', 'i'], 'robocups'],
#  [['pavel', 'i'], 'andrev976'],
#  [['pavel', 'i'], 'kares0x'],
#  [['pavel', 'i'], 'kargakis'],
#  [['pavel', 'i'], 'vetri02'],
#  [['pavel', 'i'], 'jcarvajalmunera'],
#  [['pavel', 'i'], 'hommy-huang'],
#  [['pavel', 'i'], 'celir'],
#  [['pavel', 'i'], 'imgsu'],
#  [['jammie', 'i'], 'kares0x'],
# ...

# %%
david.Names.values
# Out:
# array(['metaversityman', 'toicours', 'sstklen', 'inomfood', 'beidahuang',
#        'imnisen', 'zkfib', 'weitezhh', 'mathje', 'goodluckysix', 'ponyzz',
#        'rootphantomer', 'm-dennis', 'coinbina', 'abc2371681', 'ywu127',
#        'itachi003', 'wwy108', 'tedscript', 'kodiak-1988', 'gyb691128',
#        'zerokarafont', 'niktak11', 'qq554172', 'okhui3', 'blue8848',
#        'cainky', 'mcan455', 'grappeape', 'smallnash', 'curi0n',
#        'foggy001', 'llllonewolflll', 'daver7675', 'ljqzzz123',
#        'perstarkse', 'eliwoodd', 'haitangkeji', 'fyq517', 'liingfeng',
#        'tertower', 'tomitorres93', 't0bid', 'zijianliu', 'stephenmullens',
#        'klialek', 'microdoraset', 'xiaoxiaoleo', 'yanikj', 'elhamata',
#        'birdbeyondl', 'lincentdeng', 'bh153', 'jixiaobing5', 'wawappp',
#        'itmessage', 'jiangtaoliu', 'ferendo', 'szzcming', 'aarriiaamm'],
#       dtype=object)

# %%
handles = data.Names.value_counts()[:20].index

# %%
def word_freq(df, phrase):
    df.dropna(inplace=True)
    df_T = df[df["Is Sybil? (T or F)"] == "T"]
    df_F = df[df["Is Sybil? (T or F)"] == "F"]
    
    combined_T = ",".join(df_T.Notes)
    combined_F = ",".join(df_F.Notes)
    
    tokenized_T = sent_tokenize(combined_T)
    tokenized_F = sent_tokenize(combined_F)
    
    statements_T = []
    for j in range(len(tokenized_T)):
        for i in range(len(tokenized_T[j].split(","))):
            statement = tokenized_T[j].split(",")[i]
            statements_T.append(statement)
            
    statements_F = []
    for j in range(len(tokenized_F)):
        for i in range(len(tokenized_F[j].split(","))):
            statement = tokenized_F[j].split(",")[i]
            statements_F.append(statement)
            
    freq_F = find_counts(statements_F, phrase)
    freq_T = find_counts(statements_T, phrase)
    
    return freq_F

# %%
for i in words_:
    word_freq(bfa, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 1 of new account
# There are 13 of new account
# There are 0 of no activity
# There are 1 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 1, 0, 0, 0, 0]
frequency_T = [0, 13, 1, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (BFA)")
plt.xticks(rotation=90);

# %%
plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (BFA)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(lkh, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 1 of new account
# There are 0 of no activity
# There are 2 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 1 of new gitcoin
# There are 4 of new gitcoin
# There are 0 of new gitcoin and github
# There are 2 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 0, 0, 1, 0]
frequency_T = [0, 1, 2, 0, 4, 2]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (LKH)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (LKH)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(zerb, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 5 of new account
# There are 4 of no activity
# There are 14 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 4, 0, 0, 0]
frequency_T = [0, 5, 14, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (ZER)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (ZER)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(pavel, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 1 of new account
# There are 0 of new account
# There are 0 of no activity
# There are 0 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 1, 0, 0, 0, 0]
frequency_T = [0, 0, 0, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (PAVEL)")
plt.xticks(rotation=90);
#plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (PAVEL)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(jammie, i)
# Out:
# There are 7 of new github
# There are 3 of new github
# There are 0 of new account
# There are 1 of new account
# There are 5 of no activity
# There are 14 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 1 of new gitcoin
# There are 11 of new gitcoin
# There are 0 of new gitcoin and github
# There are 11 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [7, 0, 5, 0, 1, 0]
frequency_T = [3, 1, 14, 0, 11, 11]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (JAMMIE)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (JAMMIE)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(walter, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 0 of no activity
# There are 0 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 1 of new gitcoin
# There are 3 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 0, 0, 1, 0]
frequency_T = [0, 0, 0, 0, 3, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (WALTER)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (WALTER)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(chance, i)
# Out:
# There are 6 of new github
# There are 18 of new github
# There are 0 of new account
# There are 0 of new account
# There are 4 of no activity
# There are 15 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 8 of new gitcoin
# There are 20 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [6, 0, 4, 0, 8, 0]
frequency_T = [18, 0, 15, 0, 20, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (CHANCE)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (CHANCE)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(ann, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 0 of no activity
# There are 3 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 1 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 0, 0, 1, 0]
frequency_T = [0, 0, 3, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (ANN)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (ANN)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(dogg, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 1 of no activity
# There are 14 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 1, 0, 0, 0]
frequency_T = [0, 0, 14, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (DOGG)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (DOGG)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(sid, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 0 of no activity
# There are 0 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
for i in words_:
    word_freq(joe, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 0 of no activity
# There are 0 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
for i in words_:
    word_freq(fizzy, i)
# Out:
# There are 4 of new github
# There are 12 of new github
# There are 1 of new account
# There are 1 of new account
# There are 4 of no activity
# There are 6 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 9 of new gitcoin
# There are 18 of new gitcoin
# There are 1 of new gitcoin and github
# There are 4 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [4, 1, 4, 0, 9, 1]
frequency_T = [12, 1, 6, 0, 18, 4]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (FIZZY)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (FIZZY)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(am, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 8 of new account
# There are 5 of new account
# There are 7 of no activity
# There are 4 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 8, 7, 0, 0, 0]
frequency_T = [0, 5, 4, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (AM)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (AM)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(mount, i)
# Out:
# There are 0 of new github
# There are 7 of new github
# There are 1 of new account
# There are 0 of new account
# There are 6 of no activity
# There are 4 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 2 of new gitcoin
# There are 1 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 1, 6, 0, 2, 0]
frequency_T = [7, 0, 4, 0, 1, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (MOUNT)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (MOUNT)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(vik, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 1 of no activity
# There are 6 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 1, 0, 0, 0]
frequency_T = [0, 0, 6, 0, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (VIK)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (VIK)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(emmanuel, i)
# Out:
# There are 1 of new github
# There are 3 of new github
# There are 0 of new account
# There are 1 of new account
# There are 6 of no activity
# There are 6 of no activity
# There are 0 of inactivity
# There are 0 of inactivity
# There are 0 of new gitcoin
# There are 5 of new gitcoin
# There are 0 of new gitcoin and github
# There are 2 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [1, 0, 6, 0, 0, 0]
frequency_T = [3, 1, 6, 0, 5, 2]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (EMMANUEL)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (EMMANUEL)")
plt.xticks(rotation=90);

# %%
for i in words_:
    word_freq(greg, i)
# Out:
# There are 0 of new github
# There are 0 of new github
# There are 0 of new account
# There are 0 of new account
# There are 0 of no activity
# There are 0 of no activity
# There are 7 of inactivity
# There are 6 of inactivity
# There are 0 of new gitcoin
# There are 0 of new gitcoin
# There are 0 of new gitcoin and github
# There are 0 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [0, 0, 0, 7, 0, 0]
frequency_T = [0, 0, 0, 6, 0, 0]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class (GREG)")
plt.xticks(rotation=90);
plt.show()

plot_sns = sns.barplot(general_frequency["phrase"], general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class (GREG)")
plt.xticks(rotation=90);

# %%
data_T = data[data["Is Sybil? (T or F)"] == "T"]
data_F = data[data["Is Sybil? (T or F)"] == "F"]

# %%
data_T.to_csv("./True_cases.csv")
data_F.to_csv("./False_cases.csv")

# %%
combined_T = ",".join(data_T.Notes)
combined_F = ",".join(data_F.Notes)

# %%
combined_T.to_csv("./combined_True_cases")
combined_F.to_csv("./combined_False_cases")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13752/1042185540.py in <module>
# ----> 1 combined_T.to_csv("./combined_True_cases")
#       2 combined_F.to_csv("./combined_False_cases")
#
# AttributeError: 'str' object has no attribute 'to_csv'

# %%
df_T = pd.DataFrame([combined_T], columns = ["Combined_notes_True"])
df_F = pd.DataFrame([combined_F], columns = ["Combined_notes_False"])

# %%
df_T.to_csv("./combined_T.csv")
df_F.to_csv("./combined_F.csv")

# %%
df_T
# Out:
#                                  Combined_notes_True
# 0  Both github & gitcoin are fairly old, but inac...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
tokenized_T = sent_tokenize(combined_T)
tokenized_F = sent_tokenize(combined_F)

# %%
len(tokenized_F)
# Out:
# 68

# %%
import nltk.data

# %%
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")

# %%
statements_T = []
for j in range(len(tokenized_T)):
    for i in range(len(tokenized_T[j].split(","))):
        statement = tokenized_T[j].split(",")[i]
        statements_T.append(statement)

# %%
pd.DataFrame(statements_F, columns=["Notes"]).to_csv("./tokenized_F.csv")

# %%
df_T

# %%
statements_F = []
for j in range(len(tokenized_F)):
    for i in range(len(tokenized_F[j].split(","))):
        statement = tokenized_F[j].split(",")[i]
        statements_F.append(statement)

# %%
def find_counts(data, phrase):
    x = 0
    for i in range(len(data)):
        if phrase in data[i].lower():
            x += 1
            
    return print("There are {} of {}".format(x, phrase))

# %%
for i in words_:
    find_counts(statements_F, i)
# Out:
# There are 23 of new github
# There are 12 of new account
# There are 42 of no activity
# There are 7 of inactivity
# There are 23 of new gitcoin
# There are 1 of new gitcoin and github

# %%
find_counts(statements_F, "new github")
# Out:
# There are 17 of new github

# %%
find_counts(statements_F, "new account")
# Out:
# There are 12 of new account

# %%
find_count(statements_F, "no activity")
# Out:
# the number of no activity is: 42

# %%
find_counts(statements_F, "inactivity")
# Out:
# There are 7 of inactivity

# %%
find_counts(statements_F, "new gitcoin")
# Out:
# There are 19 of new gitcoin

# %%
find_counts(statements_F, "new gitcoin and github")
# Out:
# There are 1 of new gitcoin and github

# %%
find_counts(statements_T, "new github")
find_counts(statements_T, "new account")
find_counts(statements_T, "no activity")
find_counts(statements_T, "inactivity")
find_counts(statements_T, "new gitcoin")
find_counts(statements_T, "new gitcoin and github")
# Out:
# There are 59 of new github
# There are 27 of new account
# There are 98 of no activity
# There are 6 of inactivity
# There are 62 of new gitcoin
# There are 19 of new gitcoin and github

# %%
words_ = ["new github", "new account","no activity", "inactivity", "new gitcoin", "new gitcoin and github"]
frequency_F = [17, 12, 42, 7, 19, 1]
frequency_T = [33, 17, 82, 6, 54, 17]

general_frequency = pd.DataFrame()
general_frequency["phrase"] = words_
general_frequency["counts in False cases"] = frequency_F
general_frequency["counts in True cases"] = frequency_T
general_frequency.head(6)
# Out:
#                    phrase  counts in False cases  counts in True cases
# 0              new github                     17                    33
# 1             new account                     12                    17
# 2             no activity                     42                    82
# 3              inactivity                      7                     6
# 4             new gitcoin                     19                    54
# 5  new gitcoin and github                      1                    17

# %%
counts = general_frequency["counts in False cases"]
labels = general_frequency.phrase
plt.figure(figsize=(6, 5))
#plt.style.use("default")
plt.pie(counts, autopct= "%.1f%%", shadow=True)
circle = plt.Circle(xy=(0,0), radius=.75, facecolor="white")
plt.gca().add_artist(circle)
plt.title("Phrase frequency for the False class", weight='bold', size=14)
plt.axis("equal")
plt.legend(labels=labels, loc="best", bbox_to_anchor=(1,0.8))
plt.show()

# %%
counts = general_frequency["counts in True cases"]
labels = general_frequency.phrase
plt.figure(figsize=(6, 5))
#plt.style.use("default")
plt.pie(counts, autopct= "%.1f%%", shadow=True)
circle = plt.Circle(xy=(0,0), radius=.75, facecolor="white")
plt.gca().add_artist(circle)
plt.title("Phrase frequency for the True class", weight='bold', size=14)
plt.axis("equal")
plt.legend(labels=labels, loc="best", bbox_to_anchor=(1,0.8))
plt.show()

# %%
plot_sns = sns.barplot(y=general_frequency["phrase"], x=general_frequency["counts in True cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class", weight="bold", size=14)
plt.xticks();

# %%
plot_sns = sns.barplot(y=general_frequency["phrase"], x=general_frequency["counts in False cases"],
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False case", weight="bold", size=14)
plt.xticks();

# %%
plt.barh(pd.Series(statements_T).value_counts()[:20].index, pd.Series(statements_T).value_counts()[:20].values)
plt.title("Word frequency for the True case (Is Sybil)", weight="bold", size=14)
plt.xticks();

# %%
plt.barh(pd.Series(statements_F).value_counts()[:20].index, pd.Series(statements_F).value_counts()[:20].values)
plt.title("Word frequency for the False case (Not Sybil)", weight="bold", size=14)
plt.xticks();

# %% [markdown]
# ## WORD TOKENIZER

# %%
from nltk.tokenize import word_tokenize

# %%
def remove_punc(txt_punct):
    """
    This function removes the punctuation marks in the tokenized words.
    It takes the tokenized words as the input.
    """
    import string
    txt_nopunc = [c for c in txt_punct  if c not in string.punctuation]
    return txt_nopunc

# %%
pd.Series(remove_punc(word_tokenize(combined_T))).value_counts()[:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13752/3034670264.py in <module>
# ----> 1 pd.Series(remove_punc(word_tokenize(combined_T))).value_counts()[:20]
#
# NameError: name 'combined_T' is not defined

# %%
import nltk
stopwords = nltk.corpus.stopwords.words("english")
def remove_stopwords(txt_tokenized):
    """
    This is used to remove the unnecessary words from the text.
    """
    txt_clean = [word for word in txt_tokenized if word.lower() not in stopwords]
    return txt_clean

# %%
lowered_T = []
for i in remove_stopwords(remove_punc(word_tokenize(combined_T))):
    lowered_T.append(i.lower())

# %%
plot_sns = sns.barplot(pd.Series(lowered_T).value_counts()[:20].index, pd.Series(lowered_T).value_counts()[:20].values,
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the True class")
plt.xticks(rotation=90);

# %% [markdown]
# ## False cases

# %%
pd.Series(remove_punc(word_tokenize(combined_F))).value_counts()[:20]
# Out:
# activity         187
# account          187
# on               178
# with             169
# gitcoin          158
# github           156
# contributions    123
# and              121
# Gitcoin          117
# in               117
# of               107
# but              103
# no                92
# active            88
# Github            87
# a                 83
# GitHub            74
# to                72
# new               71
# is                62
# dtype: int64

# %%
lowered_F = []
for i in remove_stopwords(remove_punc(word_tokenize(combined_F))):
    lowered_F.append(i.lower())

# %%
plot_sns = sns.barplot(pd.Series(lowered_F).value_counts()[:20].index, pd.Series(lowered_F).value_counts()[:20].values,
                       color = "lightskyblue", palette="rocket")
plt.title("Word frequency for the False class")
plt.xticks(rotation=90);

# %%
counts = pd.Series(lowered_F).value_counts()[:10].values
labels = pd.Series(lowered_F).value_counts()[:10].keys()
plt.figure(figsize=(6, 5))
#plt.style.use("default")
plt.pie(counts, autopct= "%.1f%%", shadow=True)
circle = plt.Circle(xy=(0,0), radius=.75, facecolor="white")
plt.gca().add_artist(circle)
plt.title("Word frequency for the False class")
plt.axis("equal")
plt.legend(labels=labels, loc="best", bbox_to_anchor=(1,0.8))
plt.show()
